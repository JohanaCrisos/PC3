# %%
import pandas as pd
link1='https://raw.githubusercontent.com/JohanaCrisos/PC3/refs/heads/main/Education%20expenditures.csv'
tabla1=pd.read_csv(link1)

link2='https://raw.githubusercontent.com/JohanaCrisos/PC3/refs/heads/main/Electricity%20-%20installed%20generating%20capacity.csv'
tabla2=pd.read_csv(link2)

link3='https://raw.githubusercontent.com/JohanaCrisos/PC3/refs/heads/main/Energy%20consumption%20per%20capita.csv'
tabla3=pd.read_csv(link3)

link4='https://raw.githubusercontent.com/JohanaCrisos/PC3/refs/heads/main/Reserves%20of%20foreign%20exchange%20and%20gold.csv'
tabla4=pd.read_csv(link4)

# %%
#Iniciamos limpiando las columnas
#quitar los espacios iniciales y finales de las columnas y sustituir
#los espacios entre lineas con _
tabla1.columns=tabla1.columns.str.strip().str.replace(r'\s+', '_', regex=True)
#tambien se arregló los nombres de las columnas
tabla1.columns=tabla1.columns.str.title()
tabla1.columns
# Out:
# Index(['Name', 'Slug', '%_Of_Gdp', 'Date_Of_Information', 'Ranking', 'Region'], dtype='object')

# %%
tabla2.columns=tabla2.columns.str.strip().str.replace(r'\s+', '_', regex=True)
tabla2.columns=tabla2.columns.str.title()
tabla2.columns
# Out:
# Index(['Name', 'Slug', 'Kw', 'Date_Of_Information', 'Ranking', 'Region'], dtype='object')

# %%
tabla3.columns=tabla3.columns.str.strip().str.replace(r'\s+', '_', regex=True)
tabla3.columns=tabla3.columns.str.title()
tabla3.columns
# Out:
# Index(['Name', 'Slug', 'Btu/Person', 'Date_Of_Information', 'Ranking',
#        'Region'],
#       dtype='object')

# %%
tabla4.columns=tabla4.columns.str.strip().str.replace(r'\s+', '_', regex=True)
tabla4.columns=tabla4.columns.str.title()
tabla4.columns
# Out:
# Index(['Name', 'Slug', 'Value', 'Date_Of_Information', 'Ranking', 'Region'], dtype='object')

# %%
#Ver si hay datos faltantes en las tablas
tabla1[tabla1.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Name, Slug, %_Of_Gdp, Date_Of_Information, Ranking, Region]
# Index: []

# %%
tabla2[tabla2.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Name, Slug, Kw, Date_Of_Information, Ranking, Region]
# Index: []

# %%
tabla3[tabla3.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Name, Slug, Btu/Person, Date_Of_Information, Ranking, Region]
# Index: []

# %%
tabla4[tabla4.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Name, Slug, Value, Date_Of_Information, Ranking, Region]
# Index: []

# %%
tabla1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 197 non-null    object
#  1   Slug                 197 non-null    object
#  2   %_Of_Gdp             197 non-null    float64
#  3   Date_Of_Information  197 non-null    int64
#  4   Ranking              197 non-null    int64
#  5   Region               197 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 9.4+ KB

# %%
tabla2.info()
#la columna de Kw deberia ser numerica
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 211 non-null    object
#  1   Slug                 211 non-null    object
#  2   Kw                   211 non-null    object
#  3   Date_Of_Information  211 non-null    int64
#  4   Ranking              211 non-null    int64
#  5   Region               211 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 10.0+ KB

# %%
tabla3.info()
#la columna Btu/Person deberia ser numerica
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 195 non-null    object
#  1   Slug                 195 non-null    object
#  2   Btu/Person           195 non-null    object
#  3   Date_Of_Information  195 non-null    int64
#  4   Ranking              195 non-null    int64
#  5   Region               195 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 9.3+ KB

# %%
tabla4.info()
#la columna Value deberia ser numerica
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 195 non-null    object
#  1   Slug                 195 non-null    object
#  2   Value                195 non-null    object
#  3   Date_Of_Information  195 non-null    int64
#  4   Ranking              195 non-null    int64
#  5   Region               195 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 9.3+ KB

# %%
#analizaremos los "objetos extraños" en la tabla 2
pd.unique(tabla2.Kw[~tabla2.Kw.astype(str).str.contains(r'\d+\.\d+', regex=True)])
# Out:
# array(['2,949,000,000', '1,235,000,000', '499,136,000', '361,617,000',
#        '301,926,000', '275,658,000', '240,251,000', '161,988,000',
#        '151,463,000', '151,139,000', '130,366,000', '128,692,000',
#        '119,620,000', '114,749,000', '108,193,000', '106,281,000',
#        '105,586,000', '86,058,000', '85,725,000', '70,826,000',
#        '65,989,000', '64,806,000', '64,535,000', '60,297,000',
#        '59,982,000', '59,680,000', '55,971,000', '55,307,000',
#        '47,631,000', '44,462,000', '43,512,000', '41,100,000',
#        '39,238,000', '37,220,000', '33,493,000', '33,371,000',
#        '31,339,000', '29,174,000', '28,248,000', '27,624,000',
#        '26,782,000', '26,502,000', '25,409,000', '24,169,000',
#        '22,699,000', '22,612,000', '22,591,000', '21,802,000',
#        '21,053,000', '20,794,000', '20,294,000', '19,748,000',
#        '17,901,000', '16,164,000', '14,829,000', '14,615,000',
#        '13,300,000', '13,134,000', '12,939,000', '12,738,000',
# ...

# %%
#reemplazamos las , por espacios en blanco
tabla2['Kw']=tabla2['Kw'].astype(str).str.strip().str.replace(r',', '', regex=True)
tabla2['Kw']
# Out:
# 0      2949000000
# 1      1235000000
# 2       499136000
# 3       361617000
# 4       301926000
#           ...
# 206         12000
# 207         10000
# 208          6000
# 209          5000
# 210          3000
# Name: Kw, Length: 211, dtype: object

# %%
#analizaremos los "objetos extraños" en la tabla 3
pd.unique(tabla3['Btu/Person'][~tabla3['Btu/Person'].astype(str).str.contains(r'\d+\.\d+', regex=True)])
# Out:
# array(['814,308,000', '643,259,000', '554,202,000', '450,432,000',
#        '403,365,000', '389,848,000', '349,692,000', '311,599,000',
#        '296,586,000', '278,474,000', '261,142,000', '234,698,000',
#        '234,668,000', '224,858,000', '224,651,000', '223,158,000',
#        '206,961,000', '206,102,000', '190,416,000', '185,536,000',
#        '183,540,000', '172,936,000', '160,779,000', '153,952,000',
#        '150,555,000', '143,149,000', '142,102,000', '136,306,000',
#        '129,504,000', '127,582,000', '123,526,000', '122,737,000',
#        '121,647,000', '120,457,000', '120,211,000', '116,811,000',
#        '113,837,000', '113,805,000', '113,163,000', '112,437,000',
#        '110,114,000', '107,188,000', '104,821,000', '104,502,000',
#        '104,409,000', '103,651,000', '102,171,000', '101,120,000',
#        '100,844,000', '99,578,000', '98,847,000', '98,513,000',
#        '96,797,000', '96,152,000', '94,280,000', '92,693,000',
# ...

# %%
#reemplazamos las , por espacios en blanco
tabla3['Btu/Person']=tabla3['Btu/Person'].astype(str).str.strip().str.replace(r',', '', regex=True)
tabla3['Btu/Person']
# Out:
# 0      814308000
# 1      643259000
# 2      554202000
# 3      450432000
# 4      403365000
#          ...
# 190      1502000
# 191      1305000
# 192       954000
# 193       946000
# 194       649000
# Name: Btu/Person, Length: 195, dtype: object

# %%
#analizaremos los "objetos extraños" en la tabla 4
pd.unique(tabla4.Value[~tabla4.Value.astype(str).str.contains(r'\d+\.\d+', regex=True)])
# Out:
# array(['$3,450,000,000,000', '$1,295,000,000,000', '$863,892,000,000',
#        '$773,426,000,000', '$627,793,000,000', '$597,217,000,000',
#        '$457,949,000,000', '$456,700,000,000', '$425,554,000,000',
#        '$420,930,000,000', '$359,835,000,000', '$355,021,000,000',
#        '$322,700,000,000', '$247,396,000,000', '$240,792,000,000',
#        '$224,470,000,000', '$214,317,000,000', '$204,661,000,000',
#        '$193,783,000,000', '$189,491,000,000', '$177,915,000,000',
#        '$148,379,000,000', '$146,359,000,000', '$140,858,000,000',
#        '$120,600,000,000', '$117,551,000,000', '$113,463,000,000',
#        '$112,233,000,000', '$109,371,000,000', '$103,742,000,000',
#        '$103,089,000,000', '$92,427,000,000', '$92,238,000,000',
#        '$81,217,000,000', '$80,459,000,000', '$73,000,000,000',
#        '$71,394,000,000', '$69,830,000,000', '$62,492,000,000',
#        '$61,703,000,000', '$60,863,000,000', '$59,041,000,000',
# ...

# %%
#reemplazamos las , y $ por espacios en blanco
tabla4['Value']=tabla4['Value'].astype(str).str.strip().str.replace(r',', '', regex=True)
tabla4['Value']=tabla4['Value'].astype(str).str.strip().str.replace(r'^\$', '', regex=True)
tabla4['Value']
# Out:
# 0      3450000000000
# 1      1295000000000
# 2       863892000000
# 3       773426000000
# 4       627793000000
#            ...
# 190         76380000
# 191         49000000
# 192         47580000
# 193         46247000
# 194         30450000
# Name: Value, Length: 195, dtype: object

# %%
#convertir los valores a numericos
tabla2.Kw=pd.to_numeric(tabla2.Kw, errors='coerce')
tabla2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 211 non-null    object
#  1   Slug                 211 non-null    object
#  2   Kw                   211 non-null    int64
#  3   Date_Of_Information  211 non-null    int64
#  4   Ranking              211 non-null    int64
#  5   Region               211 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 10.0+ KB

# %%
tabla3['Btu/Person']=pd.to_numeric(tabla3['Btu/Person'], errors='coerce')
tabla3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 195 non-null    object
#  1   Slug                 195 non-null    object
#  2   Btu/Person           195 non-null    int64
#  3   Date_Of_Information  195 non-null    int64
#  4   Ranking              195 non-null    int64
#  5   Region               195 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 9.3+ KB

# %%
tabla4.Value=pd.to_numeric(tabla4.Value, errors='coerce')
tabla4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 195 non-null    object
#  1   Slug                 195 non-null    object
#  2   Value                195 non-null    int64
#  3   Date_Of_Information  195 non-null    int64
#  4   Ranking              195 non-null    int64
#  5   Region               195 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 9.3+ KB

# %%
#Al tener todas las tablas limpias iniciamos con el merge

# %%
tabla1.shape, tabla2.shape,tabla3.shape, tabla4.shape
#identificamos el número de filas y columnas, tambien queremos ver las columnas de las tablas que queremos unir
# Out:
# ((197, 6), (211, 6), (195, 6), (195, 6))

# %%
tabla3.columns
# Out:
# Index(['Name', 'Slug', 'Btu/Person', 'Date_Of_Information', 'Ranking',
#        'Region'],
#       dtype='object')

# %%
tabla4.columns
# Out:
# Index(['Name', 'Slug', 'Value', 'Date_Of_Information', 'Ranking', 'Region'], dtype='object')

# %%
#Iniciaremos analizando la tabla 3 y 4
#elementos que son diferentes de la tabla 3 y 4 usando la columna Slug
solotabla3=set(tabla3.Slug)-set(tabla4.Slug)
solotabla3
# Out:
# {'american-samoa',
#  'bermuda',
#  'british-virgin-islands',
#  'guam',
#  'kiribati',
#  'korea-north',
#  'puerto-rico'}

# %%
#elementos son diferentes de la tabla 3 y 4
solotabla4=set(tabla4.Slug)-set(tabla3.Slug)
solotabla4
# Out:
# {'anguilla',
#  'iceland',
#  'micronesia-federated-states-of',
#  'montserrat',
#  'palau',
#  'san-marino',
#  'trinidad-and-tobago'}

# %%
# !pip install thefuzz

# %%
from thefuzz import process as fz
[(c,fz.extractOne(c,solotabla3)) for c in sorted(solotabla4)]
# Out:
# [('anguilla', ('guam', 50)),
#  ('iceland', ('british-virgin-islands', 64)),
#  ('micronesia-federated-states-of', ('puerto-rico', 47)),
#  ('montserrat', ('korea-north', 38)),
#  ('palau', ('puerto-rico', 51)),
#  ('san-marino', ('american-samoa', 55)),
#  ('trinidad-and-tobago', ('kiribati', 43))]

# %%
#los datos no presentan un alto grado de similitud
#por lo que no puede haber una correcta recuperacion de datos.
tabla34=tabla3.merge(tabla4,left_on='Slug', right_on='Slug')
tabla34
# Out:
#                                 Name_x                              Slug  \
# 0                                Qatar                             qatar
# 1                            Singapore                         singapore
# 2                              Bahrain                           bahrain
# 3                 United Arab Emirates              united-arab-emirates
# 4                               Brunei                            brunei
# ..                                 ...                               ...
# 183                               Chad                              chad
# 184  Congo, Democratic Republic of the  congo-democratic-republic-of-the
# 185           Central African Republic          central-african-republic
# 186                            Burundi                           burundi
# 187                            Somalia                           somalia
#
#      Btu/Person  Date_Of_Information_x  Ranking_x                 Region_x  \
# ...

# %%
#procedemos a borrar las columnas que no son necesarias por ahora
tabla34.drop(['Ranking_x','Region_y','Ranking_y','Name_y','Date_Of_Information_x','Date_Of_Information_y'], axis=1, inplace=True)

# %%
tabla34.head()
# Out:
#                  Name_x                  Slug  Btu/Person  \
# 0                 Qatar                 qatar   814308000
# 1             Singapore             singapore   643259000
# 2               Bahrain               bahrain   554202000
# 3  United Arab Emirates  united-arab-emirates   450432000
# 4                Brunei                brunei   403365000
#
#                   Region_x         Value
# 0              Middle East   51539000000
# 1  East and Southeast Asia  359835000000
# 2              Middle East    5118000000
# 3              Middle East  189491000000
# 4  East and Southeast Asia    4483000000

# %%
#pasamos a analizar la tabla 1 y 2
tabla1.columns
# Out:
# Index(['Name', 'Slug', '%_Of_Gdp', 'Date_Of_Information', 'Ranking', 'Region'], dtype='object')

# %%
tabla2.columns
# Out:
# Index(['Name', 'Slug', 'Kw', 'Date_Of_Information', 'Ranking', 'Region'], dtype='object')

# %%
#elementos que son diferentes de la tabla 1 y 2 usando la columna Slug
solotabla1=set(tabla1.Slug)-set(tabla2.Slug)
solotabla1
# Out:
# {'andorra',
#  'anguilla',
#  'curacao',
#  'liechtenstein',
#  'marshall-islands',
#  'micronesia-federated-states-of',
#  'monaco',
#  'palau',
#  'san-marino'}

# %%
#elementos son diferentes de la tabla 1 y 2
solotabla2=set(tabla2.Slug)-set(tabla1.Slug)
solotabla2
# Out:
# {'american-samoa',
#  'bosnia-and-herzegovina',
#  'cuba',
#  'equatorial-guinea',
#  'eritrea',
#  'falkland-islands-islas-malvinas',
#  'french-polynesia',
#  'gibraltar',
#  'guam',
#  'korea-north',
#  'kosovo',
#  'libya',
#  'montenegro',
#  'new-caledonia',
#  'niue',
#  'north-macedonia',
#  'saint-helena-ascension-and-tristan-da-cunha',
#  'saint-pierre-and-miquelon',
#  'sudan',
#  'syria',
#  'taiwan',
#  'virgin-islands',
#  'yemen'}

# %%
#unimos ambas tablas
tabla12=tabla1.merge(tabla2,left_on='Slug', right_on='Slug')
tabla12
# Out:
#                Name_x              Slug  %_Of_Gdp  Date_Of_Information_x  \
# 0     Solomon Islands   solomon-islands      12.8                   2020
# 1            Kiribati          kiribati      12.4                   2019
# 2           Greenland         greenland      10.2                   2019
# 3             Bolivia           bolivia       9.8                   2020
# 4             Namibia           namibia       9.6                   2021
# ..                ...               ...       ...                    ...
# 183             Haiti             haiti       1.4                   2020
# 184  Papua New Guinea  papua-new-guinea       1.4                   2020
# 185         Venezuela         venezuela       1.3                   2017
# 186           Nigeria           nigeria       0.5                   2013
# 187           Somalia           somalia       0.3                   2019
#
#      Ranking_x                           Region_x            Name_y        Kw  \
# ...

# %%
from thefuzz import process as fz
[(c,fz.extractOne(c,solotabla1)) for c in sorted(solotabla2)]
# los datos no presentan un alto índice de similitud por lo que no podemos recuperar datos correctamente
# Out:
# [('american-samoa', ('monaco', 60)),
#  ('bosnia-and-herzegovina', ('andorra', 53)),
#  ('cuba', ('curacao', 68)),
#  ('equatorial-guinea', ('palau', 54)),
#  ('eritrea', ('micronesia-federated-states-of', 51)),
#  ('falkland-islands-islas-malvinas', ('marshall-islands', 86)),
#  ('french-polynesia', ('micronesia-federated-states-of', 48)),
#  ('gibraltar', ('palau', 54)),
#  ('guam', ('anguilla', 50)),
#  ('korea-north', ('andorra', 51)),
#  ('kosovo', ('micronesia-federated-states-of', 36)),
#  ('libya', ('liechtenstein', 51)),
#  ('montenegro', ('monaco', 60)),
#  ('new-caledonia', ('monaco', 54)),
#  ('niue', ('liechtenstein', 51)),
#  ('north-macedonia', ('monaco', 60)),
#  ('saint-helena-ascension-and-tristan-da-cunha', ('andorra', 57)),
#  ('saint-pierre-and-miquelon', ('san-marino', 51)),
#  ('sudan', ('san-marino', 68)),
#  ('syria', ('micronesia-federated-states-of', 54)),
#  ('taiwan', ('liechtenstein', 54)),
#  ('virgin-islands', ('marshall-islands', 63)),
# ...

# %%
#procedemos a borrar las columnas que no son necesarias por ahora
tabla12.drop(['Ranking_x','Region_y','Ranking_y','Name_y','Date_Of_Information_x','Date_Of_Information_y'], axis=1, inplace=True)

# %%
tabla12.head()
# Out:
#             Name_x             Slug  %_Of_Gdp               Region_x       Kw
# 0  Solomon Islands  solomon-islands      12.8  Australia and Oceania    37000
# 1         Kiribati         kiribati      12.4  Australia and Oceania    12000
# 2        Greenland        greenland      10.2          North America   190000
# 3          Bolivia          bolivia       9.8          South America  4375000
# 4          Namibia          namibia       9.6                 Africa   646000

# %%
#Analizaremos la tabla12 y 34
solotabla12=set(tabla12.Slug)-set(tabla34.Slug)
solotabla12
# Out:
# {'bermuda',
#  'british-virgin-islands',
#  'cook-islands',
#  'faroe-islands',
#  'greenland',
#  'iceland',
#  'kiribati',
#  'montserrat',
#  'nauru',
#  'puerto-rico',
#  'trinidad-and-tobago',
#  'turks-and-caicos-islands'}

# %%
#Analizaremos la tabla12 y 34
solotabla34=set(tabla34.Slug)-set(tabla12.Slug)
solotabla34
# Out:
# {'bosnia-and-herzegovina',
#  'cuba',
#  'equatorial-guinea',
#  'eritrea',
#  'kosovo',
#  'libya',
#  'montenegro',
#  'north-macedonia',
#  'sudan',
#  'syria',
#  'taiwan',
#  'yemen'}

# %%
tablaunida=tabla12.merge(tabla34,left_on='Slug', right_on='Slug')
tablaunida
# Out:
#              Name_x_x              Slug  %_Of_Gdp  \
# 0     Solomon Islands   solomon-islands      12.8
# 1             Bolivia           bolivia       9.8
# 2             Namibia           namibia       9.6
# 3        Sierra Leone      sierra-leone       9.1
# 4              Belize            belize       8.7
# ..                ...               ...       ...
# 171             Haiti             haiti       1.4
# 172  Papua New Guinea  papua-new-guinea       1.4
# 173         Venezuela         venezuela       1.3
# 174           Nigeria           nigeria       0.5
# 175           Somalia           somalia       0.3
#
#                             Region_x_x        Kw          Name_x_y  \
# 0                Australia and Oceania     37000   Solomon Islands
# 1                        South America   4375000           Bolivia
# 2                               Africa    646000           Namibia
# 3                               Africa    149000      Sierra Leone
# ...

# %%
from thefuzz import process as fz
[(c,fz.extractOne(c,solotabla12)) for c in sorted(solotabla34)]
# los datos no presentan un alto índice de similitud por lo que no podemos recuperar datos correctamente
# Out:
# [('bosnia-and-herzegovina', ('nauru', 51)),
#  ('cuba', ('bermuda', 51)),
#  ('equatorial-guinea', ('bermuda', 49)),
#  ('eritrea', ('puerto-rico', 51)),
#  ('kosovo', ('turks-and-caicos-islands', 43)),
#  ('libya', ('kiribati', 54)),
#  ('montenegro', ('montserrat', 60)),
#  ('north-macedonia', ('nauru', 45)),
#  ('sudan', ('turks-and-caicos-islands', 54)),
#  ('syria', ('montserrat', 54)),
#  ('taiwan', ('trinidad-and-tobago', 54)),
#  ('yemen', ('greenland', 54))]

# %%
#procedemos a eliminar columnas innecesarias
tablaunida.drop(['Region_x_y','Slug','Name_x_y'], axis=1, inplace=True)

# %%
# renombrar columna
tablaunida = tablaunida.rename(columns={'Name_x_x':'Country', '%_Of_Gdp':'%_of_GDP','Kw':'KW', 'Region_x_x':'Region'})

# %%
tablaunida.head()
# Out:
#            Country  %_of_GDP                             Region       KW  \
# 0  Solomon Islands      12.8              Australia and Oceania    37000
# 1          Bolivia       9.8                      South America  4375000
# 2          Namibia       9.6                             Africa   646000
# 3     Sierra Leone       9.1                             Africa   149000
# 4           Belize       8.7  Central America and the Caribbean   220000
#
#    Btu/Person       Value
# 0     5655000   688220000
# 1    29340000  1800000000
# 2    21734000  2956000000
# 3     2301000   495699000
# 4    30752000   473729000

# %%
tablaunida.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     176 non-null    object
#  1   %_of_GDP    176 non-null    float64
#  2   Region      176 non-null    object
#  3   KW          176 non-null    int64
#  4   Btu/Person  176 non-null    int64
#  5   Value       176 non-null    int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 8.4+ KB

# %%
#Determinaremos los valores promedio, mínimo y máximo en base a las regiones
varsAggregated=['%_of_GDP','KW','Btu/Person','Value']
funciones=['mean','min','max']
tablaregion=tablaunida.groupby('Region')[varsAggregated].agg(funciones)
#y procedemos a hacer 'FLAT' por si queremos exportar el trabajo a otra aplicacion
#de esta manera aseguramos que los datos se visualicen correctamente
#tablaregion.columns=['_'.join(col) for col in tablaregion.columns.to_flat_index()]
tablaregion
# Out:
#                                    %_of_GDP                       KW  \
#                                        mean  min   max          mean
# Region
# Africa                             4.268000  0.3   9.6  4.619820e+06
# Australia and Oceania              6.314286  2.2  12.8  1.706100e+07
# Central America and the Caribbean  4.555000  1.4   8.7  1.580500e+06
# Central Asia                       4.333333  2.8   6.2  4.239578e+07
# East and Southeast Asia            3.633333  1.4   6.3  2.108446e+08
# Europe                             5.151429  3.1   7.2  4.027509e+07
# Middle East                        4.528571  1.7   7.8  3.381729e+07
# North America                      5.200000  4.3   6.1  5.008580e+08
# South America                      4.808333  1.3   9.8  3.550408e+07
# South Asia                         3.850000  1.9   7.0  7.211612e+07
#
#                                                             Btu/Person  \
# ...

# %%
#Ahora podemos proseguir con el establecimiento de intervalos para cada variable
# !pip install mapclassify

# %%
import mapclassify
import numpy as np
K=5
#iniciamos con la columna %_of_GDP
#Se eligió el método FisherJenks
#Encuentra el esquema de clasificación óptimo minimizando la varianza dentro de las clases y maximizando la varianza entre clases. Su objetivo es crear las clases más homogéneas posibles.
intervaloGDP=mapclassify.FisherJenks(tablaunida['%_of_GDP'], k=K)
intervaloGDP
# Out:
# FisherJenks
#
#    Interval      Count
# ----------------------
# [ 0.30,  2.70] |    26
# ( 2.70,  4.10] |    52
# ( 4.10,  5.60] |    55
# ( 5.60,  7.80] |    36
# ( 7.80, 12.80] |     7

# %%
#se repite la acción para cada columna
intervaloKW=mapclassify.FisherJenks(tablaunida['KW'], k=K)
intervaloBTU=mapclassify.FisherJenks(tablaunida['Btu/Person'], k=K)
intervaloVALUE=mapclassify.FisherJenks(tablaunida['Value'], k=K)

# %%
#ahora agregaremos los intervalos en forma de columnas
tablaunida['Intervalo_GDP']=intervaloGDP.yb
tablaunida['Intervalo_KW']=intervaloKW.yb
tablaunida['Intervalo_BTU']=intervaloBTU.yb
tablaunida['Intervalo_VALUE']=intervaloVALUE.yb
tablaunida
# Out:
#               Country                             Region  %_of_GDP  \
# 0     Solomon Islands              Australia and Oceania      12.8
# 1             Bolivia                      South America       9.8
# 2             Namibia                             Africa       9.6
# 3        Sierra Leone                             Africa       9.1
# 4              Belize  Central America and the Caribbean       8.7
# ..                ...                                ...       ...
# 171             Haiti  Central America and the Caribbean       1.4
# 172  Papua New Guinea            East and Southeast Asia       1.4
# 173         Venezuela                      South America       1.3
# 174           Nigeria                             Africa       0.5
# 175           Somalia                             Africa       0.3
#
#      Intervalo_GDP        KW  Intervalo_KW  Btu/Person  Intervalo_BTU  \
# 0                4     37000             0     5655000              0
# ...

# %%
#Ahora podemos reorganizar las columnas para tener un mejor orden
nuevoorden=['Country','Region','%_of_GDP','Intervalo_GDP','KW','Intervalo_KW','Btu/Person','Intervalo_BTU','Value','Intervalo_VALUE']
tablaunida=tablaunida.reindex(columns=nuevoorden)
tablaunida
# Out:
#               Country                             Region  %_of_GDP  \
# 0     Solomon Islands              Australia and Oceania      12.8
# 1             Bolivia                      South America       9.8
# 2             Namibia                             Africa       9.6
# 3        Sierra Leone                             Africa       9.1
# 4              Belize  Central America and the Caribbean       8.7
# ..                ...                                ...       ...
# 171             Haiti  Central America and the Caribbean       1.4
# 172  Papua New Guinea            East and Southeast Asia       1.4
# 173         Venezuela                      South America       1.3
# 174           Nigeria                             Africa       0.5
# 175           Somalia                             Africa       0.3
#
#      Intervalo_GDP        KW  Intervalo_KW  Btu/Person  Intervalo_BTU  \
# 0                4     37000             0     5655000              0
# ...

# %%
#lo guardamos usando pickle
tablaunida.to_pickle("tabla.pkl")
dfPickle=pd.read_pickle("tabla.pkl")
dfPickle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          176 non-null    object
#  1   Region           176 non-null    object
#  2   %_of_GDP         176 non-null    float64
#  3   Intervalo_GDP    176 non-null    int64
#  4   KW               176 non-null    int64
#  5   Intervalo_KW     176 non-null    int64
#  6   Btu/Person       176 non-null    int64
#  7   Intervalo_BTU    176 non-null    int64
#  8   Value            176 non-null    int64
#  9   Intervalo_VALUE  176 non-null    int64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 13.9+ KB
